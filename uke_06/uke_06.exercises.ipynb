# %% [markdown]
# # Uke 6

# %% [markdown]
# ### Exercise 1
# What is the final value of `position` in the program below? (Try to predict the
# value without running the program, then check your prediction.)
#
# ```python
# initial = "left"
# position = initial
# initial = "right"
# ```

# %% [markdown]
# ### Exercise 2
# What are the values of the variables in this program after each statement is
# executed. In simple terms, what do the last three lines of this program do?
#
# ```python
# lowest = 1.0
# highest = 3.0
# temp = lowest
# lowest = highest
# highest = temp
# ```

# %% [markdown]
# ### Exercise 3
#
# Which is a better variable name, `m`, `min`, or `minutes`? Why? Hint: think
# about which code you find easier to understand:
#
# ```python
# ts = m * 60 + s
# tot_sec = min * 60 + sec
# total_seconds = minutes * 60 + seconds
# ```

# %% [markdown]
# ### Exercise 4
# What type of value is 4? And 3.4? How can you find out?

# %% [markdown]
# ### Exercise 5
# What type of value is 3.4 + 4? Use a variable to store the result of the
# calculation. Think of the answer *before* you try to find out using python.

# %% [markdown]
# ### Exercise 6
# Finish this code so that it gives the desired output.
#
# Code:
#
# ```python
# result = 3.4 + 4
# text = __________
# print(text, 'is', type(text))
# ```
#
# Output:
#
# ```python
# 7.4 is <class 'str'>
# ```

# %% [markdown]
# ### Exercise 7
# Finish this code so that it gives the desired output.
#
# Code:
#
# ```python
# a = "3.4"
# b = 4
# result = _____ + b
# print(result, 'is', type(result))
# ```
#
# Output:
#
# ```python
# 7.4 is <class 'float'>
# ```

# %% [markdown]
# ### Exercise 8
# What type of value (integer, floating point number, or character string) would
# you use to represent each of the following?
#
# 1. Number of days since the start of the year.
# 1. A lab specimen's name.
# 1. A lab specimen's age.
# 1. Current population of a city.
# 1. Average population density of a country.

# %% [markdown]
# ### Exercise 9
# Which of the following will print `2.0`? Note: there may be more than one right
# answer.
# Think of the answer *before* you check using python.
#
# ```python
# first = 1.0
# second = "1"
# third = "1.1"
#
# first + float(second)
# float(second) + float(third)
# first + int(third)
# first + int(float(third))
# int(first) + int(float(third))
# 2.0 * second
# ```

# %% [markdown]
# ### Exercise 10
# Can a newborn baby in Norway expect to live for one billion ($10^9$) seconds?
# Use Python for doing the arithmetics to answer the question.

# %% [markdown]
# ### Exercise 11
# Python has a built-in function `sum` that gives the sum of a list of numbers, and `len` that gives the length of a string *or* the number of elements in a list.
#
# Use these functions and some of the data from the pipetting lab from MBV1010 to calculate the mean weight of your measurements.

# %% [markdown]
# ### Exercise 12
# There is a pyhon package called `statistics` that has a function `mean`. Import this package and use the `mean` function to again calculate the mean weight of your measurements.

# %% [markdown]
# ### Exercise 13
# Use the built-in functions `abs()`, `round()`, `pow()`, `int()`, `float()`, and `str()` to print out the answers to the following. A built-in function is one that you don’t need to import a module to use. Use another function, `help()`, to learn how to use any of the functions that you don’t know how to use appropriately. `help()` takes one parameter, the name of the function you want information about. E.g., `help(pow)` (the equivalent of writing `?pow` ).
#
#
# 1. The absolute value of -15.5.
# 1. 3.8 rounded to the nearest integer using standard rounding.
# 1. 4.483847 rounded to one decimal place.
# 1. Convert 3.8 to an integer format using int(), assign the value to a variable, and print out it’s value.
# 1. Convert the answer to the previous question to a string and assign it back to the same variable name, print out the value.
# 1. Convert the answer to the previous question to a float and assign it back to the same variable name, print out the value.
# 1. Do you notice anything about the answer to the last question?
# 1. Take the square of the answer to the previous question, assign it the same variable name, print out the value.
