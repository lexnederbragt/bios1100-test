# %% [markdown]
# # Uke 5

# %% [markdown]
# ## Human population size
#
# The table below shows the life expectancy (in years) in Norway between 1952 and 2007 with
# five-year intervals:
#
# | Year | Life Expectancy |
# |------|-----------------|
# | 1952 | 72.67           |
# | 1957 | 73.44           |
# | 1962 | 73.47           |
# | 1967 | 74.08           |
# | 1972 | 74.34           |
# | 1977 | 75.37           |
# | 1982 | 75.97           |
# | 1987 | 75.89           |
# | 1992 | 77.32           |
# | 1997 | 78.32           |
# | 2002 | 79.05           |
# | 2007 | 80.196          |
#
# ### Exercise 1
# Generate a line plot of the life expectancy over time, with figure title and axes
# lables.

# %% [markdown]
# ------
# The table below compares the life expectancies of Norway and Sweden in the same period:
#
# | Year | Norway | Sweden|
# |------|--------|-------|
# | 1952 | 72.67  | 71.86 |
# | 1957 | 73.44  | 72.49 |
# | 1962 | 73.47  | 73.37 |
# | 1967 | 74.08  | 74.16 |
# | 1972 | 74.34  | 74.72 |
# | 1977 | 75.37  | 75.44 |
# | 1982 | 75.97  | 76.42 |
# | 1987 | 75.89  | 77.19 |
# | 1992 | 77.32  | 78.16 |
# | 1997 | 78.32  | 79.39 |
# | 2002 | 79.05  | 80.04 |
# | 2007 | 80.196 | 80.884|
#
# ### Exercise 2
# Generate a new plot of showing the life expectancies in both countries over time,
# also include a legend.

# %% [markdown]
# ### Exercise 3
# Display the helpt text for `pyplot.legend()`

# %% [markdown]
# ### Exercise 4
# Using the help text of `pyplot.legend()`, find out how to improve the figure by
# placing the legend in a different part of the plot.

# %% [markdown]
# ### Exercise 5
# What are the values of the variables in this program after each statement is
# executed. In simple terms, what do the last three lines of this program do?

# %%
lowest = 1.0
highest = 3.0
temp = lowest
lowest = highest
highest = temp

# %% [markdown]
# ### Exercise 6
# What is the final value of `position` in the program below? (Try to predict the
# value without running the program, then check your prediction.)

# %%
initial = "left"
position = initial
initial = "right"

# %% [markdown]
# ### Exercise 7
# Which is a better variable name, `m`, `min`, or `minutes`? Why? Hint: think
# about which code you find easier to understand:
#
# ```python
# ts = m * 60 + s
# tot_sec = min * 60 + sec
# total_seconds = minutes * 60 + seconds
# ```

# %% [markdown]
# ### Exercise 8
# Can a newborn baby in Norway expect to live for one billion ($10^9$) seconds?
# Use Python program for doing arithmetics to answer the question.

# %% [markdown]
# ### Exercise 9
# What type of value is 4? And 3.4? How can you find out?

# %% [markdown]
# ### Exercise 10
# What type of value is 3.4 + 4? Use a variable to store the result of the
# calculation. Think of the answer *before* you try to find out using python.

# %% [markdown]
# ### Exercise 11
# Finish this code so that it gives the desired output.
#
# Code:
#
# ```python
# result = 3.4 + 4
# text = __________
# print(text, 'is', type(text))
# ```
#
# Output:
#
# ```python
# 7.4 is <class 'str'>
# ```

# %% [markdown]
# ### Exercise 12
# Finish this code so that it gives the desired output.
#
# Code:
#
# ```python
# a = "3.4"
# b = 4
# result = _____ + b
# print(result, 'is', type(result))
# ```
#
# Output:
#
# ```python
# 7.4 is <class 'float'>
# ```

# %% [markdown]
# ### Exercise 13
# What type of value (integer, floating point number, or character string) would
# you use to represent each of the following?
#
# 1. Number of days since the start of the year.
# 1. A lab specimen's name.
# 1. A lab specimen's age.
# 1. Current population of a city.
# 1. Average population density of a country.

# %% [markdown]
# ### Exercise 14
#
# Which of the following will print `2.0`? Note: there may be more than one right
# answer.
# Think of the answer *before* you check using python.
#
# ```python
# first = 1.0
# second = "1"
# third = "1.1"
#
# first + float(second)
# float(second) + float(third)
# first + int(third)
# first + int(float(third))
# int(first) + int(float(third))
# 2.0 * second
# ```
