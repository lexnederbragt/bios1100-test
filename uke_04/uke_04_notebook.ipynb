# %% [markdown]
# My *first* notebook in **python**
#
# * første
# * andre
# * tredje
#
#
#
# 1. første
# 2. andre
# 3. noenannet

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
t = [0, 30, 60, 90, 120, 150, 180, 210, 240]

# %%
print(t)
# Out:
# [0, 30, 60, 90, 120, 150, 180, 210, 240]

# %%
print("t")
# Out:
# t

# %%
E = [10000, 10000, 10000, 25587, 76327, 212715, 619511, 1940838, 4240760]

# %%
print(E)
# Out:
# [10000, 10000, 10000, 25587, 76327, 212715, 619511, 1940838, 4240760]

# %%
print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bb2ea196f768> in <module>()
# ----> 1 print(e)
#
# NameError: name 'e' is not defined

# %%
from matplotlib import pyplot

# %%
# %matplotlib inline

# %%
pyplot.plot(t, E)
pyplot.show()

# %%
pyplot.plot(t, E)
pyplot.xlabel("t(minutes)")
pyplot.ylabel("Population size, E")
pyplot.show()

# %% [markdown]
# **Exercise:** find a new datapoint between t = 150 og t = 225 and add it to the lists and plot

# %%
t2 = [0, 30, 60, 90, 120, 150, 180, 190, 210, 240]
E2 = [10000, 10000, 10000, 25587, 76327, 212715, 619511, 1000000, 1940838, 4240760]
pyplot.plot(t2, E2)
pyplot.xlabel("t(minutes)")
pyplot.ylabel("Population size, E")
pyplot.show()
